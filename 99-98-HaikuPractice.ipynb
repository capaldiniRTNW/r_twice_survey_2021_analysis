# %%
def()

# %%
import random

# %%
def line_one_length(x):
    if x <= 3:
        l = 1
    elif x <= 22:
        l = 2
    elif x <= 46:
        l = 3
    elif x <= 71:
        l = 4
    elif x <= 78:
        l = 5
    else:
        l = 6
    return l


def line_two_length(x):
    if x <= 7:
        l = 2
    elif x <= 32:
        l = 3
    elif x <= 60:
        l = 4
    elif x <= 76:
        l = 5
    else:
        l = 6
    return l


def line_three_length(x):
    if x <= 7:
        l = 1
    elif x <= 35:
        l = 2
    elif x <= 62:
        l = 3
    elif x <= 73:
        l = 4
    elif x <= 77:
        l = 5
    else:
        l = 6
    return l

a = random.randint(1, 79)
b = random.randint(1, 79)
c = random.randint(1, 79)
print(a, b, c)
print(line_one_length(a), line_two_length(b), line_three_length(c))

print("Haiku: \n 3 _ _ _ \n 2 _ _ \n 3 _ _ _")
# Out:
# 53 66 52
# 4 5 3

# %%
import random

def line_one_length(x):
    if x <= 3:
        l = 1
    elif x <= 22:
        l = 2
    elif x <= 46:
        l = 3
    elif x <= 71:
        l = 4
    elif x <= 78:
        l = 5
    else:
        l = 6
    return l


def line_two_length(x):
    if x <= 7:
        l = 2
    elif x <= 32:
        l = 3
    elif x <= 60:
        l = 4
    elif x <= 76:
        l = 5
    else:
        l = 6
    return l


def line_three_length(x):
    if x <= 7:
        l = 1
    elif x <= 35:
        l = 2
    elif x <= 62:
        l = 3
    elif x <= 73:
        l = 4
    elif x <= 77:
        l = 5
    else:
        l = 6
    return l

a = random.randint(1, 79)
b = random.randint(1, 79)
c = random.randint(1, 79)

l1 = line_one_length(a)
l2 = line_two_length(b)
l3 = line_three_length(c)

print(f"Haiku: \n {l1} {'_ ' * l1}\n {l2} {'_ ' * l2}\n {l3} {'_ ' * l3}")
# Out:
# Haiku:
#  2 _ _
#  3 _ _ _
#  1 _
